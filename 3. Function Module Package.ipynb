# %%
## Function

def fungsi_aku(nama):
    "Functionn memanggil nama aku"
    print('halo nama aku',nama)

# fungsi_aku('rubi')

nama = 'fadlil'
# fungsi_aku(nama)

# required argument
# fungsi_aku() Missing argument

# keyword 
def gabung_nama(nama_depan, nama_belakang):
    nama_lengkap = nama_depan + ' ' + nama_belakang
    print(nama_lengkap)

gabung_nama(nama_depan='rahman', nama_belakang='hasri')

# default argument
def join_list(list1=[], list2=[0, 0, 0]):
    list1.extend(list2)
    return list1

print(join_list([1, {}, 1]))

# variable length
def fungsi_argument_length(arg1, *arg2):
    print(arg1)
    print(arg2)

# fungsi_argument_length('yamaha', 'honda', 'suzuki', 'kawasaki')
help(fungsi_aku)

def change_me(dictionary, new_key, new_value):
    dictionary[new_key] = new_value
    print(dictionary)

# change_me({ 'menu': 'login' }, 'user', 'rahman')

def input_list_dari_depan(input_list, list_baru):
    if type(list_baru) == list:
        for i in range(len(list_baru)):
            input_list.insert(0, list_baru[i])
    else:
        input_list.insert(list_baru)
    return input_list

output = input_list_dari_depan([], [1,2,3,4])
# print(output)

# ANONYMOUS FUNCTION
fungsi_lambda = lambda a, b: a + b

# print(fungsi_lambda(10, 10))

extendlist = (lambda l1, l2: [l1[0], l2[0]])([2], [3, 4])

print(extendlist)



## Module


import math

# dir(srsly)

# help(math.sqrt)

a = []

help(math.sqrt)
# a.append(10)
# a

# !pip list

# %%
import wikipedia

# wikipedia.search('jokowi')

# dir(wikipedia)
wikipedia.page('Joko Widodo')
# Out:
# <WikipediaPage 'Joko Widodo'>

# %%
import requests

# dir(requests)

# help(requests.get)
# url = 'http://www.omdbapi.com/?apikey=1ff311a7&s=mandalorian'
# response = requests.get(url)

# response.json()
# Out:
# {'Search': [{'Title': 'The Mandalorian',
#    'Year': '2019–',
#    'imdbID': 'tt8111088',
#    'Type': 'series',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BZDhlMzY0ZGItZTcyNS00ZTAxLWIyMmYtZGQ2ODg5OWZiYmJkXkEyXkFqcGdeQXVyODkzNTgxMDg@._V1_SX300.jpg'},
#   {'Title': 'Disney Gallery: The Mandalorian',
#    'Year': '2020–',
#    'imdbID': 'tt12162902',
#    'Type': 'series',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BYjY0YWEzNTMtZjRlZi00MzQ1LThkMTAtMTk4OTE5MWVkYzFkXkEyXkFqcGdeQXVyODk4OTc3MTY@._V1_SX300.jpg'},
#   {'Title': 'Star Wars: Wrath of the Mandalorian',
#    'Year': '2008',
#    'imdbID': 'tt2351379',
#    'Type': 'movie',
#    'Poster': 'https://m.media-amazon.com/images/M/MV5BMTU2NzYwMzY5OV5BMl5BanBnXkFtZTcwMTQ3MDU3Nw@@._V1_SX300.jpg'},
#   {'Title': 'The Mandalorian Legacy',
#    'Year': '2009',
#    'imdbID': 'tt1260577',
#    'Type': 'movie',
# ...

# %%
url = 'http://www.omdbapi.com/?apikey=1ff311a7&i=tt8111088'
requests.get(url).json()
# Out:
# {'Title': 'The Mandalorian',
#  'Year': '2019–',
#  'Rated': 'TV-14',
#  'Released': '12 Nov 2019',
#  'Runtime': '40 min',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Director': 'N/A',
#  'Writer': 'Jon Favreau',
#  'Actors': 'Pedro Pascal',
#  'Plot': 'The travels of a lone bounty hunter in the outer reaches of the galaxy, far from the authority of the New Republic.',
#  'Language': 'English',
#  'Country': 'USA',
#  'Awards': 'Nominated for 1 Golden Globe. Another 25 wins & 37 nominations.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BZDhlMzY0ZGItZTcyNS00ZTAxLWIyMmYtZGQ2ODg5OWZiYmJkXkEyXkFqcGdeQXVyODkzNTgxMDg@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.8/10'}],
#  'Metascore': 'N/A',
#  'imdbRating': '8.8',
#  'imdbVotes': '292,961',
#  'imdbID': 'tt8111088',
#  'Type': 'series',
#  'totalSeasons': '3',
#  'Response': 'True'}

# %%
# !pip install
# !python3 -m venv venv
source ./venv/bin/activate
