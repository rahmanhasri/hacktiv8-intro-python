# %%
# !python
# !date
# Out:
# Sun Mar 14 21:19:39 WIB 2021

# %%
true=True
false=False

# %%
# type data
print('ini string')
print(9)
print(type(9))
print(type(true))
# Out:
# ini string
# 9
# <class 'int'>
# <class 'bool'>

# %%
# variable assignment
temp='life'
pi=3.14
print(pi)
# Out:
# 3.14

# %%
# operator expression
a = 2
b = a + 2
print(b)
# b + a

a ** 3
# Out:
# 4
# 8

# %%
#comparison operator
a == 2
1 == 1
true == True
'life' == 'forever'
# Out:
# False

# %%
# string manipulation
name = 'rahman'
print('nama saya ' + name)
# name*4

school = 'Hacktiv8'

print(school.upper())
print(school.swapcase())
print('HACKTIV8'.lower())
# Out:
# nama saya rahman
# HACKTIV8
# hACKTIV8
# hacktiv8

# %%
# List
l = [1, 2, 3, 4, 5]
# Ordered
# 0 1 2 3 4
# arbitrary
me = ['rahman', 22, 3.14, False]

# index
me[1:]
me[:2]
l[1:3]
l[-1]

#mutable
me.append('old soul')
me[2] = 'June'
del me[3]
me

len(me)

max(l)
# modify
l[1:4] = [9, 8, 7]
l

# nested
l.append([1])
l
# Out:
# [1, 9, 8, 7, 5, [1]]

# %%
# Tuple
t = ('raka', 'adi', 'dimitri', 'fani')
t

#immutable
# t[0] = 'Oka'

# packing unpacking

(raka, adi, dimitri, fani) = t
raka
# Out:
# 'raka'

# %%
# Dictionary
import pandas as pd
