# %%
import numpy as np

# %%
ds = [12, 24, 41, 51, 67, 67, 85, 99]
np.std(ds, ddof=1) ** 2 # sample std with ddof = 1
# Out:
# 877.3571428571428

# %% [markdown]
# ### Test markdown

# %%
# !python3 -m pip install scipy

# %%
import math
import statistics as st
import numpy as np
import scipy.stats
import pandas as pd

x = [8.0, 1, 2.5, 4, 28.0]
x_with_nan = [8.0, 1, 2.5, math.nan, 4, 28.0]


z = pd.Series(x)
print(x)
print(np.array(x))
# Out:
# [8.0, 1, 2.5, 4, 28.0]
# [ 8.   1.   2.5  4.  28. ]

# %%
x = [8.0, 1, 2.5, 4, 28.0]
w = [0.1, 0.2, 0.3, 0.25, 0.15]
wmean = sum(w[i] * x[i] for i in range(len(x)))
# wmean

price = [300, 200, 150, 100]
quantity = [20, 100, 225, 300]

sum(price[i] * quantity[i] for i in range(len(price))) / sum(quantity)
# Out:
# 139.14728682170542

# %%
st.harmonic_mean([2,4,6,100])
round(1.5)

x = [8.0, 1, 2.5, 4, 28.0]

print(st.median_high(x[:-1]))
print(x[:-1])
# Out:
# 4
# 4
# [8.0, 1, 2.5, 4]

# %%
# Mode

u = [2, 3, 2, 8, 12]
v = [12, 15, 12, 15, 21, 15,12]

# mode_ = max((u.count(item), item) for item in set(u))
# mode_
[]
print(max((u.count(item), item) for item in set(u)))

unique = set(u)
mode_ = 0
max_ = 0
for item in unique:
    if (u.count(item) > max_):
        mode_ = item
        max_ = u.count(item)


n = len(x)
mean_ = sum(x) / n
var_ = sum((item - mean_) ** 2 for item in x) / (n-1)
var_
# Out:
# (2, 2)
# 123.19999999999999
